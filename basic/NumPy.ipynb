# %%
from PIL import Image
from pylab import *
from numpy import *

# %%
'''im = array(Image.open('../img/camera.jpg'))
print(im.shape,im.dtype)

im = array(Image.open('../img/camera.jpg').convert('L'),'f')
print(im.shape, im.dtype)'''
# Out:
# "im = array(Image.open('../img/camera.jpg'))\nprint(im.shape,im.dtype)\n\nim = array(Image.open('../img/camera.jpg').convert('L'),'f')\nprint(im.shape, im.dtype)"

# %%
#灰度变换
im = array(Image.open('../img/camera.jpg').convert('L'))
im2 = 255 - im #反向
im3 = (100.0/255) * im + 100 #变换到100-200区间
im4 = 255.0 * (im/255.0)**2 #对像素值求平方
imshow(im,cmap='gray')
